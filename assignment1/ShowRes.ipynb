# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Assignment1.xlsx")
data
# Out:
#     Step  Experiment 1  Experiment 2  Experiment 3  Experiment 4  \
# 0      1      1.124680      1.167107      1.150538      1.250538
# 1      2      1.517345      1.475542      1.760952      1.620263
# 2      5      2.082230      2.058787      2.252407      2.238601
# 3     10      2.915620      2.868392      3.090635      3.235224
# 4     20      4.508325      4.176000      4.034921      4.528686
# 5     30      4.693551      4.951233      5.277417      5.256698
# 6     40      5.791723      5.327543      5.853738      5.416195
# 7     50      5.903897      5.890571      6.037011      6.309718
# 8     60      6.608521      7.156335      6.485840      6.167322
# 9     70      7.372215      7.811586      7.651796      8.129348
# 10    80      8.210661      8.375715      7.895264      7.516066
# 11    90      8.371468      8.457349      8.145365      8.345346
# 12   100      9.563019      8.925293      8.324610      8.288004
# ...

# %%
x=np.linspace(0,200,20000)
y=[math.sqrt(i) * 0.9 for i in x] 
plt.plot(x, y, label = "9/10 * x^(1/2)")
plt.plot(data["Step"], data["Mean"], label = "Mean Distance")
plt.xlabel("Step")
plt.ylabel("Distance")
plt.legend()
plt.savefig("res.png")
plt.show()
